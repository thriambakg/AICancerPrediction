# %% [markdown]
# # Reading Data
#
# This uses the data format from [Create Parsed CSV](https://colab.research.google.com/drive/14ZGZdJ4xxM0ZAwCE2zGSm0SWC6H6nWXI#scrollTo=eKqSRKQgvq7a)

# %%
ls

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# ## Read Data

# %%
# !unzip parsed_patient_data.zip
# Out:
# Archive:  parsed_patient_data.zip
# replace parsed_patient_data.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %% [markdown]
# ##Create Parsed file

# %% [markdown]
# ## Read main file

# %%
import pandas as pd

df = pd.read_csv("parsed_patient_data.csv")
df.head()
# Out:
#        0         1         2         3         4         5         6  \
# 0  232.0  0.238632  0.238474  0.238414  0.238316  0.238085  0.237769
# 1   59.0  0.216471  0.216397  0.216409  0.216444  0.216407  0.216261
# 2  213.0  0.109393  0.109271  0.109190  0.109163  0.109112  0.108990
# 3  189.0  0.099630  0.099845  0.100284  0.100685  0.100863  0.100841
# 4  221.0  0.132230  0.132424  0.132705  0.132855  0.132772  0.132543
#
#           7         8         9  ...      2440      2441      2442      2443  \
# 0  0.237522  0.237452  0.237516  ...  0.012059  0.011989  0.011871  0.011729
# 1  0.216068  0.215938  0.215913  ...  0.029054  0.029212  0.029524  0.029881
# 2  0.108815  0.108614  0.108422  ...  0.011896  0.011860  0.011968  0.012149
# 3  0.100761  0.100721  0.100710  ...  0.012581  0.012648  0.012809  0.012992
# 4  0.132363  0.132353  0.132458  ...  0.017984  0.018097  0.018312  0.018425
#
#        2444      2445      2446      2447      2448      2449
# 0  0.011601  0.011492  0.011371  0.011241  0.011164  0.011170
# 1  0.030134  0.030255  0.030323  0.030382  0.030409  0.030382
# 2  0.012291  0.012355  0.012395  0.012476  0.012592  0.012688
# 3  0.013140  0.013244  0.013323  0.013401  0.013489  0.013576
# 4  0.018313  0.018070  0.017888  0.017860  0.017904  0.017846
#
# [5 rows x 2450 columns]

# %% [markdown]
# # Parsing Features and Labels

# %%
y = df["0"]
y.head()
# Out:
# 0    232.0
# 1     59.0
# 2    213.0
# 3    189.0
# 4    221.0
# Name: 0, dtype: float64

# %%
X = df.drop("0", axis=1)
X.head()
# Out:
#           1         2         3         4         5         6         7  \
# 0  0.238632  0.238474  0.238414  0.238316  0.238085  0.237769  0.237522
# 1  0.216471  0.216397  0.216409  0.216444  0.216407  0.216261  0.216068
# 2  0.109393  0.109271  0.109190  0.109163  0.109112  0.108990  0.108815
# 3  0.099630  0.099845  0.100284  0.100685  0.100863  0.100841  0.100761
# 4  0.132230  0.132424  0.132705  0.132855  0.132772  0.132543  0.132363
#
#           8         9        10  ...      2440      2441      2442      2443  \
# 0  0.237452  0.237516  0.237566  ...  0.012059  0.011989  0.011871  0.011729
# 1  0.215938  0.215913  0.215920  ...  0.029054  0.029212  0.029524  0.029881
# 2  0.108614  0.108422  0.108292  ...  0.011896  0.011860  0.011968  0.012149
# 3  0.100721  0.100710  0.100662  ...  0.012581  0.012648  0.012809  0.012992
# 4  0.132353  0.132458  0.132511  ...  0.017984  0.018097  0.018312  0.018425
#
#        2444      2445      2446      2447      2448      2449
# 0  0.011601  0.011492  0.011371  0.011241  0.011164  0.011170
# 1  0.030134  0.030255  0.030323  0.030382  0.030409  0.030382
# 2  0.012291  0.012355  0.012395  0.012476  0.012592  0.012688
# 3  0.013140  0.013244  0.013323  0.013401  0.013489  0.013576
# 4  0.018313  0.018070  0.017888  0.017860  0.017904  0.017846
#
# [5 rows x 2449 columns]

# %% [markdown]
# ## Visualize Data

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

def visualize(index):
  print(y[index])
  plt.plot(X.loc[index].tolist())

visualize(7)
# Out:
# 36.0

# %% [markdown]
# ## Create `X` and `y` from Data

# %% [markdown]
# ### Import Tensorflow

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.head()
# Out:
#             1         2         3         4         5         6         7  \
# 79   0.169687  0.169381  0.169128  0.169079  0.169243  0.169504  0.169745
# 421  0.056905  0.056657  0.056179  0.055663  0.055363  0.055367  0.055562
# 10   0.142346  0.142326  0.142230  0.142122  0.142033  0.141948  0.141862
# 418  0.186147  0.186124  0.186015  0.185843  0.185616  0.185370  0.185175
# 160  0.281170  0.280954  0.280682  0.280514  0.280393  0.280216  0.280082
#
#             8         9        10  ...      2440      2441      2442  \
# 79   0.169898  0.169899  0.169710  ...  0.023831  0.023892  0.023920
# 421  0.055802  0.056018  0.056184  ...  0.011901  0.012030  0.012087
# 10   0.141786  0.141716  0.141610  ...  0.016484  0.016557  0.016569
# 418  0.185084  0.185070  0.185057  ...  0.003135  0.003050  0.003066
# 160  0.280183  0.280476  0.280656  ...  0.037757  0.037848  0.037765
#
#          2443      2444      2445      2446      2447      2448      2449
# 79   0.023949  0.023995  0.024048  0.024085  0.024121  0.024200  0.024339
# 421  0.012081  0.012079  0.012148  0.012275  0.012374  0.012361  0.012247
# 10   0.016558  0.016539  0.016529  0.016572  0.016686  0.016807  0.016862
# 418  0.003138  0.003201  0.003200  0.003122  0.003004  0.002920  0.002950
# 160  0.037579  0.037351  0.037141  0.037038  0.037110  0.037322  0.037554
#
# [5 rows x 2449 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler = scaler.fit(X_train)

X_train_norm = scaler.transform(X_train)
X_test_norm = scaler.transform(X_test)

# %% [markdown]
# ## Convert to Tensors

# %%
X_train = tf.constant(X_train, dtype=tf.float32)
X_test = tf.constant(X_test, dtype=tf.float32)
y_train = tf.constant(y_train, dtype=tf.float32)
y_test = tf.constant(y_test, dtype=tf.float32)

# %% [markdown]
# # Creating Model

# %%
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import *
import matplotlib.pyplot as plt
import pandas as pd

# %%
tf.random.set_seed(50)

model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])


model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   metrics=["mae"])

history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=200,
                              validation_data=(X_train_norm, y_train))

# %%
pd.DataFrame(history_1.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_1.evaluate(X_test_norm, y_test)

# %% [markdown]
# # Installing TensorflowJS
#
# We need this for when we save models

# %%
# !pip install tensorflowjs

# %% [markdown]
# ### ***MY*** ***STUFF***

# %%
tf.random.set_seed(50)

model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dense(1)
])

model_mark.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adagrad(),
              metrics=["mae"])
history_mark = model_mark.fit(X_train_norm,
                        y_train,
                        epochs=100)

pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_mark.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_mark2 = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dense(1)
])

model_mark2.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.AdamW(),
              metrics=["mae"])
history_mark2 = model_mark2.fit(X_train_norm,
                        y_train,
                        epochs=100)

pd.DataFrame(history_mark2.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_mark2.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_mark3 = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dense(1)
])

model_mark3.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adamax(),
              metrics=["mae"])
history_mark3 = model_mark3.fit(X_train_norm,
                        y_train,
                        epochs=100)

pd.DataFrame(history_mark3.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_mark3.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_mark4 = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dense(1)
])

model_mark4.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Nadam(),
              metrics=["mae"])
history_mark4 = model_mark4.fit(X_train_norm,
                        y_train,
                        epochs=100)

pd.DataFrame(history_mark4.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_mark4.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dense(1)
])

model_1.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

history_1 = model_1.fit(X_train_norm, y_train, epochs=100)

pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_mark.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])


model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   metrics=["mae"])

history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=200,
                              validation_data=(X_train_norm, y_train))

pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
model_mark.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(500, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   metrics=["mae"])

history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=300,
                              validation_data=(X_train_norm, y_train))

pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")

model_mark.evaluate(X_test_norm, y_test)

# %%
tf.random.set_seed(50)

model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   metrics=["mae"])

# Implementing a learning rate scheduler
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5, verbose=1)

history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=300,
                              validation_data=(X_train_norm, y_train),
                              callbacks=[lr_scheduler])

pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")

model_mark.evaluate(X_test_norm, y_test)

model_mark.save("model_mark.h5")

# %%
tf.random.set_seed(50)

model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.001),
                   metrics=["mae"])

history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=300,
                              validation_data=(X_train_norm, y_train))

pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")

model_mark.evaluate(X_test_norm, y_test)

# %%
# Set random seed for reproducibility
tf.random.set_seed(50)

# Define the model
model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Normalization(axis = 1)
])

# Compile the model with a lower learning rate
model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.0001),
                   metrics=["mae"])

# Train the model
history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=50,
                              validation_data=(X_test_norm, y_test))

# Plot the training history
pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
plt.show()

# Evaluate the model on the test set
model_mark.evaluate(X_test_norm, y_test)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 2s 56ms/step - loss: 137.3343 - mae: 137.3343 - val_loss: 125.8535 - val_mae: 125.8535
# Epoch 2/50
# 12/12 [==============================] - 0s 38ms/step - loss: 115.5443 - mae: 115.5443 - val_loss: 101.5633 - val_mae: 101.5633
# Epoch 3/50
# 12/12 [==============================] - 0s 34ms/step - loss: 93.2848 - mae: 93.2848 - val_loss: 82.5401 - val_mae: 82.5401
# Epoch 4/50
# 12/12 [==============================] - 0s 37ms/step - loss: 76.8159 - mae: 76.8159 - val_loss: 67.9947 - val_mae: 67.9947
# Epoch 5/50
# 12/12 [==============================] - 0s 35ms/step - loss: 65.3776 - mae: 65.3776 - val_loss: 61.9041 - val_mae: 61.9041
# Epoch 6/50
# 12/12 [==============================] - 1s 44ms/step - loss: 63.9105 - mae: 63.9105 - val_loss: 60.7545 - val_mae: 60.7545
# Epoch 7/50
# 12/12 [==============================] - 0s 37ms/step - loss: 63.3155 - mae: 63.3155 - val_loss: 60.9665 - val_mae: 60.9665
# Epoch 8/50
# 12/12 [==============================] - 0s 34ms/step - loss: 62.6728 - mae: 62.6728 - val_loss: 60.4200 - val_mae: 60.4200
# Epoch 9/50
# 12/12 [==============================] - 0s 33ms/step - loss: 63.6799 - mae: 63.6799 - val_loss: 60.3576 - val_mae: 60.3576
# Epoch 10/50
# 12/12 [==============================] - 0s 39ms/step - loss: 62.3408 - mae: 62.3408 - val_loss: 60.5574 - val_mae: 60.5574
# Epoch 11/50
# 12/12 [==============================] - 0s 33ms/step - loss: 61.7569 - mae: 61.7569 - val_loss: 60.2807 - val_mae: 60.2807
# Epoch 12/50
# 12/12 [==============================] - 0s 34ms/step - loss: 62.2257 - mae: 62.2257 - val_loss: 60.0756 - val_mae: 60.0756
# Epoch 13/50
# 12/12 [==============================] - 0s 37ms/step - loss: 61.8267 - mae: 61.8267 - val_loss: 60.3171 - val_mae: 60.3171
# Epoch 14/50
# 12/12 [==============================] - 0s 34ms/step - loss: 62.2687 - mae: 62.2687 - val_loss: 59.9564 - val_mae: 59.9564
# Epoch 15/50
# 12/12 [==============================] - 0s 35ms/step - loss: 61.7569 - mae: 61.7569 - val_loss: 60.5345 - val_mae: 60.5345
# Epoch 16/50
# 12/12 [==============================] - 0s 33ms/step - loss: 60.6711 - mae: 60.6711 - val_loss: 59.9351 - val_mae: 59.9351
# Epoch 17/50
# 12/12 [==============================] - 0s 34ms/step - loss: 62.2003 - mae: 62.2003 - val_loss: 59.9150 - val_mae: 59.9150
# Epoch 18/50
# 12/12 [==============================] - 0s 39ms/step - loss: 60.2762 - mae: 60.2762 - val_loss: 59.7683 - val_mae: 59.7683
# Epoch 19/50
# 12/12 [==============================] - 0s 33ms/step - loss: 60.8386 - mae: 60.8386 - val_loss: 59.9875 - val_mae: 59.9875
# Epoch 20/50
# 12/12 [==============================] - 0s 37ms/step - loss: 61.9634 - mae: 61.9634 - val_loss: 59.5250 - val_mae: 59.5250
# Epoch 21/50
# 12/12 [==============================] - 0s 35ms/step - loss: 61.6825 - mae: 61.6825 - val_loss: 59.3057 - val_mae: 59.3057
# Epoch 22/50
# 12/12 [==============================] - 0s 35ms/step - loss: 62.8995 - mae: 62.8995 - val_loss: 59.2511 - val_mae: 59.2511
# Epoch 23/50
# 12/12 [==============================] - 0s 38ms/step - loss: 61.8158 - mae: 61.8158 - val_loss: 59.1467 - val_mae: 59.1467
# Epoch 24/50
# 12/12 [==============================] - 1s 51ms/step - loss: 61.6650 - mae: 61.6650 - val_loss: 59.0663 - val_mae: 59.0663
# Epoch 25/50
# 12/12 [==============================] - 1s 52ms/step - loss: 61.0482 - mae: 61.0482 - val_loss: 58.9647 - val_mae: 58.9647
# Epoch 26/50
# 12/12 [==============================] - 1s 57ms/step - loss: 60.1729 - mae: 60.1729 - val_loss: 59.5974 - val_mae: 59.5974
# Epoch 27/50
# 12/12 [==============================] - 1s 50ms/step - loss: 61.8235 - mae: 61.8235 - val_loss: 58.8113 - val_mae: 58.8113
# Epoch 28/50
# 12/12 [==============================] - 1s 51ms/step - loss: 61.4235 - mae: 61.4235 - val_loss: 59.1286 - val_mae: 59.1286
# Epoch 29/50
# 12/12 [==============================] - 1s 48ms/step - loss: 61.1047 - mae: 61.1047 - val_loss: 58.7482 - val_mae: 58.7482
# Epoch 30/50
# 12/12 [==============================] - 0s 39ms/step - loss: 60.0367 - mae: 60.0367 - val_loss: 58.8183 - val_mae: 58.8183
# Epoch 31/50
# 12/12 [==============================] - 0s 39ms/step - loss: 59.6853 - mae: 59.6853 - val_loss: 58.4321 - val_mae: 58.4321
# Epoch 32/50
# 12/12 [==============================] - 0s 38ms/step - loss: 61.7407 - mae: 61.7407 - val_loss: 58.6218 - val_mae: 58.6218
# Epoch 33/50
# 12/12 [==============================] - 0s 34ms/step - loss: 60.7560 - mae: 60.7560 - val_loss: 58.2550 - val_mae: 58.2550
# Epoch 34/50
# 12/12 [==============================] - 0s 34ms/step - loss: 60.2681 - mae: 60.2681 - val_loss: 58.6059 - val_mae: 58.6059
# Epoch 35/50
# 12/12 [==============================] - 0s 37ms/step - loss: 60.6172 - mae: 60.6172 - val_loss: 59.4533 - val_mae: 59.4533
# Epoch 36/50
# 12/12 [==============================] - 0s 33ms/step - loss: 60.5359 - mae: 60.5359 - val_loss: 58.1175 - val_mae: 58.1175
# Epoch 37/50
# 12/12 [==============================] - 0s 41ms/step - loss: 59.8842 - mae: 59.8842 - val_loss: 57.9116 - val_mae: 57.9116
# Epoch 38/50
# 12/12 [==============================] - 1s 46ms/step - loss: 59.2463 - mae: 59.2463 - val_loss: 58.2351 - val_mae: 58.2351
# Epoch 39/50
# 12/12 [==============================] - 1s 48ms/step - loss: 60.9119 - mae: 60.9119 - val_loss: 57.7940 - val_mae: 57.7940
# Epoch 40/50
# 12/12 [==============================] - 0s 35ms/step - loss: 59.4170 - mae: 59.4170 - val_loss: 57.6780 - val_mae: 57.6780
# Epoch 41/50
# 12/12 [==============================] - 0s 35ms/step - loss: 59.0764 - mae: 59.0764 - val_loss: 57.9355 - val_mae: 57.9355
# Epoch 42/50
# 12/12 [==============================] - 0s 35ms/step - loss: 59.7214 - mae: 59.7214 - val_loss: 57.4726 - val_mae: 57.4726
# Epoch 43/50
# 12/12 [==============================] - 0s 36ms/step - loss: 58.2687 - mae: 58.2687 - val_loss: 57.4455 - val_mae: 57.4455
# Epoch 44/50
# 12/12 [==============================] - 1s 52ms/step - loss: 60.2661 - mae: 60.2661 - val_loss: 57.2308 - val_mae: 57.2308
# Epoch 45/50
# 12/12 [==============================] - 1s 45ms/step - loss: 58.5435 - mae: 58.5435 - val_loss: 57.0016 - val_mae: 57.0016
# Epoch 46/50
# 12/12 [==============================] - 0s 34ms/step - loss: 60.7922 - mae: 60.7922 - val_loss: 57.2268 - val_mae: 57.2268
# Epoch 47/50
# 12/12 [==============================] - 0s 38ms/step - loss: 58.8580 - mae: 58.8580 - val_loss: 57.0833 - val_mae: 57.0833
# Epoch 48/50
# 12/12 [==============================] - 1s 44ms/step - loss: 56.8831 - mae: 56.8831 - val_loss: 56.6939 - val_mae: 56.6939
# Epoch 49/50
# 12/12 [==============================] - 1s 61ms/step - loss: 57.8678 - mae: 57.8678 - val_loss: 56.5646 - val_mae: 56.5646
# Epoch 50/50
# 12/12 [==============================] - 1s 49ms/step - loss: 59.2389 - mae: 59.2389 - val_loss: 57.4295 - val_mae: 57.4295
# 3/3 [==============================] - 0s 16ms/step - loss: 57.4295 - mae: 57.4295
# [57.42951202392578, 57.42951202392578]

# %%
tf.random.set_seed(50)

# Define the model
model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

# Compile the model with the Adam optimizer
model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adam(learning_rate=1),
                   metrics=["mae"])

# Train the model
history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=100,
                              validation_data=(X_test_norm, y_test))

# Plot the training history
pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
plt.show()

# Evaluate the model on the test set
model_mark.evaluate(X_test_norm, y_test)

model_mark.save("model_mark.h5")

# %% [markdown]
# Duplicate as above w/ different optimizer

# %%
tf.random.set_seed(50)

# Define the model
model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(500, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1)
])

# Compile the model with the Adam optimizer
model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adadelta(learning_rate=1),
                   metrics=["mae"])

# Train the model
history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=100,
                              validation_data=(X_test_norm, y_test))

# Plot the training history
pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
plt.show()

# Evaluate the model on the test set
model_mark.evaluate(X_test_norm, y_test)

model_mark.save("model_mark.h5")

# %%
tf.random.set_seed(50)

# Define the model with batch normalization
model_mark = tf.keras.Sequential([
    tf.keras.layers.Dense(1000, activation='relu'),
    tf.keras.layers.Normalization(),
])

# Compile the model with the Adam optimizer
model_mark.compile(loss=tf.keras.losses.mae,
                   optimizer=tf.keras.optimizers.Adam(learning_rate=1),
                   metrics=["mae"])

# Train the model
history_mark = model_mark.fit(X_train_norm,
                              y_train,
                              epochs=100,
                              validation_data=(X_test_norm, y_test))

# Plot the training history
pd.DataFrame(history_mark.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
plt.show()

# Evaluate the model on the test set
model_mark.evaluate(X_test_norm, y_test)

# Save the model
model_mark.save("model_mark.h5")

# %%
base_model = load_model('model_mark.h5')

# Freeze the base model
for layer in base_model.layers:
    layer.trainable = False

input_layer = base_model.input

# Add custom layers on top
x = base_model.layers[-1].output
x = Dense(1000, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(500, activation='relu')(x)
x = Dropout(0.5)(x)
x = Dense(1, activation='relu')(x)

predictions = x


# Combine base model and custom layers into a new model
model_transfer = Model(inputs=input_layer, outputs=predictions)

# Compile the model
model_transfer.compile(loss=tf.keras.losses.mae,
                       optimizer=RMSprop(learning_rate=0.0001),
                       metrics=["mae"])

# Train the model
history_transfer = model_transfer.fit(X_train_norm,
                                       y_train,
                                       epochs=100,
                                       validation_data=(X_train_norm, y_train))

# Plot the training history
pd.DataFrame(history_transfer.history).plot()
plt.ylabel("Loss Function")
plt.xlabel("Epochs")
plt.show()

# Evaluate the model on the test set
model_transfer.evaluate(X_test_norm, y_test)
